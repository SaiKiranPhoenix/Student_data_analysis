# %%
import pandas as pd
import numpy as np
import seaborn as sns
import ChernoffFace as cf
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("C:/Users\Saikiran_Phoenix/Desktop/New folder/student.csv")
data
# Out:
#                               Name       RollNo  Age  Gender  SSC GPA Caste  \
# 0                     Bakam Anusri   19VD1A0501   21  Female      9.7   OBC
# 1                      ARUN KUMAR    19VD1A0503   20    Male      8.0    ST
# 2                 Ankola Ashritha   19VD1A0504    21  Female      9.2   OBC
# 3        Dharavath Chenna kesavulu   19VD1A0508   21    Male      7.0    ST
# 4               BUSHI DAVID SAMUEL   19VD1A0509   21    Male      7.4   OBC
# ..                             ...          ...  ...     ...      ...   ...
# 259                        Umadevi   22VD5A6608   20  Female      9.2   OBC
# 260  GOSHIKA VARAHA NAGA HARSHINI    22VD5A6609   18  Female      8.7    SC
# 261                 Ganta Vinkitha   22VD5A6610   19  Female      9.8    OC
# 262             Basidi Vivek Teja    22VD5A6611   19    Male      8.5   OBC
# 263                  BODDU AKHILA   22VDIA6605    19  Female      8.3   OBC
#
#             Standard  Year of joining Most Fav Sport  \
# 0    B.TECH 4TH YEAR             2019      BadMinton
# 1    B.TECH 4TH YEAR             2019        Cricket
# 2    B.TECH 4TH YEAR             2019   Online Games
# 3    B.TECH 4TH YEAR             2019      BadMinton
# 4    B.TECH 4TH YEAR             2019        Cricket
# ..               ...              ...            ...
# 259  B.TECH 2ND YEAR             2022        Kabaddi
# 260  B.TECH 2ND YEAR             2022        Cricket
# 261  B.TECH 2ND YEAR             2022      BadMinton
# 262  B.TECH 2ND YEAR             2022   Online Games
# 263  B.TECH 1ST YEAR             2022   Online Games
#
#     Which sector you are interested in? Pursuing B.Tech With  \
# 0                        Private Sector        Self Interest
# 1                        Private Sector        Self Interest
# 2                        Private Sector        Self Interest
# 3                     Government Sector        Self Interest
# 4                     Government Sector        Self Interest
# ..                                  ...                  ...
# 259                      Private Sector        Self Interest
# 260                   Government Sector        Self Interest
# 261                      Private Sector        Self Interest
# 262                   Government Sector        Self Interest
# 263                   Government Sector        Self Interest
#
#     Do You have backlogs                      Hobbies  \
# 0                     No                        Books
# 1                     No  Sports, Music, Books, Dance
# 2                     No                 Music, Books
# 3                     No                Sports, Music
# 4                     No                        Dance
# ..                   ...                          ...
# 259                   No          Music, Books, Dance
# 260                   No                 Music, Books
# 261                   No         Sports, Music, Books
# 262                   No                  Arts, Music
# 263                   No                        Music
#
#                          Your best skill
# 0                   Communication Skills
# 1    Critical Thinking & Problem Solving
# 2                       Logical thinking
# 3                               Teamwork
# 4    Critical Thinking & Problem Solving
# ..                                   ...
# 259  Critical Thinking & Problem Solving
# 260                 Communication Skills
# 261                 Communication Skills
# 262                             Teamwork
# 263                     Logical thinking
#
# [264 rows x 14 columns]

# %%
df=pd.DataFrame(data)

# %%
cff=df.Age.unique()
cff
# Out:
# array([21, 20, 22, 19, 18, 17], dtype=int64)

# %%
data.head()
# Out:
#                         Name       RollNo  Age  Gender  SSC GPA Caste  \
# 0               Bakam Anusri   19VD1A0501   21  Female      9.7   OBC
# 1                ARUN KUMAR    19VD1A0503   20    Male      8.0    ST
# 2           Ankola Ashritha   19VD1A0504    21  Female      9.2   OBC
# 3  Dharavath Chenna kesavulu   19VD1A0508   21    Male      7.0    ST
# 4         BUSHI DAVID SAMUEL   19VD1A0509   21    Male      7.4   OBC
#
#           Standard  Year of joining Most Fav Sport  \
# 0  B.TECH 4TH YEAR             2019      BadMinton
# 1  B.TECH 4TH YEAR             2019        Cricket
# 2  B.TECH 4TH YEAR             2019   Online Games
# 3  B.TECH 4TH YEAR             2019      BadMinton
# 4  B.TECH 4TH YEAR             2019        Cricket
#
#   Which sector you are interested in? Pursuing B.Tech With  \
# 0                      Private Sector        Self Interest
# 1                      Private Sector        Self Interest
# 2                      Private Sector        Self Interest
# 3                   Government Sector        Self Interest
# 4                   Government Sector        Self Interest
#
#   Do You have backlogs                      Hobbies  \
# 0                   No                        Books
# 1                   No  Sports, Music, Books, Dance
# 2                   No                 Music, Books
# 3                   No                Sports, Music
# 4                   No                        Dance
#
#                        Your best skill
# 0                 Communication Skills
# 1  Critical Thinking & Problem Solving
# 2                     Logical thinking
# 3                             Teamwork
# 4  Critical Thinking & Problem Solving

# %%
data.tail()
# Out:
#                               Name       RollNo  Age  Gender  SSC GPA Caste  \
# 259                        Umadevi   22VD5A6608   20  Female      9.2   OBC
# 260  GOSHIKA VARAHA NAGA HARSHINI    22VD5A6609   18  Female      8.7    SC
# 261                 Ganta Vinkitha   22VD5A6610   19  Female      9.8    OC
# 262             Basidi Vivek Teja    22VD5A6611   19    Male      8.5   OBC
# 263                  BODDU AKHILA   22VDIA6605    19  Female      8.3   OBC
#
#             Standard  Year of joining Most Fav Sport  \
# 259  B.TECH 2ND YEAR             2022        Kabaddi
# 260  B.TECH 2ND YEAR             2022        Cricket
# 261  B.TECH 2ND YEAR             2022      BadMinton
# 262  B.TECH 2ND YEAR             2022   Online Games
# 263  B.TECH 1ST YEAR             2022   Online Games
#
#     Which sector you are interested in? Pursuing B.Tech With  \
# 259                      Private Sector        Self Interest
# 260                   Government Sector        Self Interest
# 261                      Private Sector        Self Interest
# 262                   Government Sector        Self Interest
# 263                   Government Sector        Self Interest
#
#     Do You have backlogs               Hobbies  \
# 259                   No   Music, Books, Dance
# 260                   No          Music, Books
# 261                   No  Sports, Music, Books
# 262                   No           Arts, Music
# 263                   No                 Music
#
#                          Your best skill
# 259  Critical Thinking & Problem Solving
# 260                 Communication Skills
# 261                 Communication Skills
# 262                             Teamwork
# 263                     Logical thinking

# %%
data.describe()
# Out:
#               Age     SSC GPA  Year of joining
# count  264.000000  264.000000       264.000000
# mean    19.041667    9.287879      2020.973485
# std      1.270522    0.675371         1.040646
# min     17.000000    7.000000      2019.000000
# 25%     18.000000    9.000000      2020.000000
# 50%     19.000000    9.500000      2021.000000
# 75%     20.000000    9.800000      2022.000000
# max     22.000000   10.000000      2022.000000

# %%
data.shape
# Out:
# (264, 14)

# %%
data.columns
# Out:
# Index(['Name', 'RollNo', 'Age', 'Gender', 'SSC GPA', 'Caste', 'Standard',
#        'Year of joining', 'Most Fav Sport',
#        'Which sector you are interested in?', 'Pursuing B.Tech With',
#        'Do You have backlogs', 'Hobbies', 'Your best skill'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Name                                   0
# RollNo                                 0
# Age                                    0
# Gender                                 0
# SSC GPA                                0
# Caste                                  0
# Standard                               0
# Year of joining                        0
# Most Fav Sport                         0
# Which sector you are interested in?    0
# Pursuing B.Tech With                   0
# Do You have backlogs                   0
# Hobbies                                0
# Your best skill                        0
# dtype: int64

# %%
#Relationshhip Analysis

# %%
cor=data.corr()
# Out:
# C:\Users\Saikiran_Phoenix\AppData\Local\Temp\ipykernel_16684\1426905697.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=data.corr()

# %%
sns.heatmap(cor,xticklabels=cor.columns,yticklabels=cor.columns,annot=True)
# Out:
# <AxesSubplot: >

# %%
sns.pairplot(cor)

# %%
sns.relplot(x='SSC GPA',y='SSC GPA',hue='Gender', data=data)

# %%
sns.histplot(data['SSC GPA'],bins=5)
# Out:
# <AxesSubplot: xlabel='SSC GPA', ylabel='Count'>

# %%
sns.catplot(x='Age',kind='box',data=data)

# %%
sns.catplot(x='Year of joining', y='Age',data=data)

# %%
np.random.seed(32)
data = np.random.rand(16, 12)

# %%
fig = cf.chernoff_face(data=data, 
                    titles=[str(x) for x in list(range(len(data)))], 
                    color_mapper=plt.cm.Pastel1)
